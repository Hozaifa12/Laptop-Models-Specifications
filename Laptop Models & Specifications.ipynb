# %% [markdown]
# # Project -Laptops model & Specification

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("laptops.csv")  #calling datasets

# %%
df  #upper5&lower5 datasets of laptops specification
# Out:
#      Unnamed: 0                                              title      price  \
# 0             0  DELL Vostro Core i3 11th Gen - (8 GB/1 TB HDD/...    ₹37,990
# 1             1  HP 14s Intel Core i3 11th Gen - (8 GB/256 GB S...    ₹35,490
# 2             2  Lenovo V15 G2 Core i3 11th Gen - (8 GB/512 GB ...    ₹33,999
# 3             3  HP 15s Intel Core i3 12th Gen - (8 GB/512 GB S...    ₹45,490
# 4             4  ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ₹33,990
# ..          ...                                                ...        ...
# 915         915  Lenovo Intel Core i7 12th Gen - (16 GB/512 GB ...  ₹1,19,990
# 916         916  DELL Core i5 11th Gen - (16 GB/512 GB SSD/Wind...    ₹68,990
# 917         917  DELL Inspiron Pentium Quad Core - (8 GB/256 GB...    ₹35,990
# 918         918  ASUS Vivobook X515EA Core i3 11th Gen - (8 GB/...    ₹36,990
# 919         919  HP Pavilion Intel Core i7 11th Gen - (16 GB/51...    ₹89,999
#
# ...

# %%
df.head()   #shows upper 5 rows&columns
# Out:
#    Unnamed: 0                                              title    price  \
# 0           0  DELL Vostro Core i3 11th Gen - (8 GB/1 TB HDD/...  ₹37,990
# 1           1  HP 14s Intel Core i3 11th Gen - (8 GB/256 GB S...  ₹35,490
# 2           2  Lenovo V15 G2 Core i3 11th Gen - (8 GB/512 GB ...  ₹33,999
# 3           3  HP 15s Intel Core i3 12th Gen - (8 GB/512 GB S...  ₹45,490
# 4           4  ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...  ₹33,990
#
#          discount                                          Processor  \
# 0  ₹58,48935% off  Processor: Intel i3-1115G4 (Base- 1.7 GHz & Tu...
# 1  ₹47,20624% off                 Intel Core i3 Processor (11th Gen)
# 2  ₹59,76043% off                 Intel Core i3 Processor (11th Gen)
# 3  ₹56,26019% off                 Intel Core i3 Processor (12th Gen)
# 4  ₹45,99026% off                 Intel Core i3 Processor (10th Gen)
#
#                                              RAM  \
# 0  RAM & Storage: 8GB DDR4 & 1TB HDD + 256GB SSD
# ...

# %%
df.tail()  #shows below 5 rows&columns
# Out:
#      Unnamed: 0                                              title      price  \
# 915         915  Lenovo Intel Core i7 12th Gen - (16 GB/512 GB ...  ₹1,19,990
# 916         916  DELL Core i5 11th Gen - (16 GB/512 GB SSD/Wind...    ₹68,990
# 917         917  DELL Inspiron Pentium Quad Core - (8 GB/256 GB...    ₹35,990
# 918         918  ASUS Vivobook X515EA Core i3 11th Gen - (8 GB/...    ₹36,990
# 919         919  HP Pavilion Intel Core i7 11th Gen - (16 GB/51...    ₹89,999
#
#              discount                                          Processor  \
# 915  ₹1,53,89022% off                 Intel Core i7 Processor (12th Gen)
# 916    ₹95,99028% off  Processor: i5-11260H (Base: 2.60 GHz up to 4.4...
# 917    ₹39,99010% off                  Intel Pentium Quad Core Processor
# 918    ₹51,99028% off                 Intel Core i3 Processor (11th Gen)
# 919  ₹1,02,50012% off                 Intel Core i7 Processor (11th Gen)
#
#                                                    RAM  \
# ...

# %%
df.shape    #quantity of rows&columns
# Out:
# (920, 11)

# %%
df.dtypes   #shows datatypes
# Out:
# Unnamed: 0      int64
# title          object
# price          object
# discount       object
# Processor      object
# RAM            object
# OS             object
# SSD            object
# Display        object
# In_build_sw    object
# warranty       object
# dtype: object

# %%
df.isnull().sum()    #returns the number of missing values in datasets
# Out:
# Unnamed: 0       0
# title            0
# price            0
# discount        89
# Processor        0
# RAM              0
# OS               0
# SSD              0
# Display          0
# In_build_sw    563
# warranty        14
# dtype: int64

# %%
df.columns     #specifies columns
# Out:
# Index(['Unnamed: 0', 'title', 'price', 'discount', 'Processor', 'RAM', 'OS',
#        'SSD', 'Display', 'In_build_sw', 'warranty'],
#       dtype='object')

# %%
df.duplicated().sum()     #shows the duplicated sums
# Out:
# 0

# %%
df.describe()      #gives the proper description of datasets
# Out:
#        Unnamed: 0
# count  920.000000
# mean   459.500000
# std    265.725422
# min      0.000000
# 25%    229.750000
# 50%    459.500000
# 75%    689.250000
# max    919.000000

# %%
df.describe(include='all')     #includes the union of attributes of each types
# Out:
#         Unnamed: 0                                              title  \
# count   920.000000                                                920
# unique         NaN                                                846
# top            NaN  Infinix X1 Slim Series Core i5 10th Gen - (8 G...
# freq           NaN                                                  4
# mean    459.500000                                                NaN
# std     265.725422                                                NaN
# min       0.000000                                                NaN
# 25%     229.750000                                                NaN
# 50%     459.500000                                                NaN
# 75%     689.250000                                                NaN
# max     919.000000                                                NaN
#
#           price        discount                           Processor  \
# ...

# %%
df.duplicated().sum()     #quantity of duplicates
# Out:
# 0

# %%
df.sample(4)   #shows the random sample of items
# Out:
#      Unnamed: 0                                              title    price  \
# 80           80  ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...  ₹48,990
# 338         338  HP OMEN Core i7 11th Gen - (16 GB/1 TB SSD/Win...  ₹99,999
# 535         535  ASUS ExpertBook P1 Core i5 10th Gen - (4 GB/1 ...  ₹61,249
# 584         584  Infinix X1 Slim Series Core i5 10th Gen - (8 G...  ₹42,990
#
#              discount                           Processor               RAM  \
# 80     ₹69,99030% off  Intel Core i5 Processor (11th Gen)     8 GB DDR4 RAM
# 338  ₹1,40,29228% off  Intel Core i7 Processor (11th Gen)    16 GB DDR4 RAM
# 535    ₹68,99011% off  Intel Core i5 Processor (10th Gen)     4 GB DDR4 RAM
# 584    ₹59,99928% off  Intel Core i5 Processor (10th Gen)  8 GB LPDDR4X RAM
#
#                                      OS         SSD  \
# 80   64 bit Windows 11 Operating System  512 GB SSD
# 338  64 bit Windows 11 Operating System    1 TB SSD
# ...

# %%
df.nunique()   #returns the no.of unique values for each column
# Out:
# Unnamed: 0     920
# title          846
# price          469
# discount       763
# Processor       92
# RAM             57
# OS              45
# SSD             52
# Display         88
# In_build_sw    118
# warranty       117
# dtype: int64

# %%
df.dropna()   #drops the null value
# Out:
#      Unnamed: 0                                              title    price  \
# 2             2  Lenovo V15 G2 Core i3 11th Gen - (8 GB/512 GB ...  ₹33,999
# 3             3  HP 15s Intel Core i3 12th Gen - (8 GB/512 GB S...  ₹45,490
# 4             4  ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...  ₹33,990
# 7             7  ASUS VivoBook K15 OLED (2022) Ryzen 5 Hexa Cor...  ₹47,990
# 8             8  HP Ryzen 5 Hexa Core 5500U - (16 GB/512 GB SSD...  ₹49,123
# ..          ...                                                ...      ...
# 905         905  DELL Core i5 11th Gen - (16 GB/512 GB SSD/Wind...  ₹67,989
# 914         914  HP Envy 13 Ryzen 5 Quad Core 3500U - (8 GB/512...  ₹87,900
# 917         917  DELL Inspiron Pentium Quad Core - (8 GB/256 GB...  ₹35,990
# 918         918  ASUS Vivobook X515EA Core i3 11th Gen - (8 GB/...  ₹36,990
# 919         919  HP Pavilion Intel Core i7 11th Gen - (16 GB/51...  ₹89,999
#
# ...

# %%
df['title'].count()    #shows the title counts
# Out:
# 920

# %%
df['RAM'].value_counts()    #shows the title counts with values specification
# Out:
# 8 GB DDR4 RAM                                                                                                                                                                                                                                                                   357
# 16 GB DDR4 RAM                                                                                                                                                                                                                                                                  188
# 16 GB DDR5 RAM                                                                                                                                                                                                                                                                   67
# ...

# %%
df['discount'].count()   #shows the discount in dataset product
# Out:
# 831

# %%
sns.heatmap(df.corr())   #shows the heatmap of datasets
plt.show()

# %%
df.drop(["SSD"],axis=1,inplace=True)    #drops the ssd column

# %%
df
# Out:
#      Unnamed: 0                                              title      price  \
# 0             0  DELL Vostro Core i3 11th Gen - (8 GB/1 TB HDD/...    ₹37,990
# 1             1  HP 14s Intel Core i3 11th Gen - (8 GB/256 GB S...    ₹35,490
# 2             2  Lenovo V15 G2 Core i3 11th Gen - (8 GB/512 GB ...    ₹33,999
# 3             3  HP 15s Intel Core i3 12th Gen - (8 GB/512 GB S...    ₹45,490
# 4             4  ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ₹33,990
# ..          ...                                                ...        ...
# 915         915  Lenovo Intel Core i7 12th Gen - (16 GB/512 GB ...  ₹1,19,990
# 916         916  DELL Core i5 11th Gen - (16 GB/512 GB SSD/Wind...    ₹68,990
# 917         917  DELL Inspiron Pentium Quad Core - (8 GB/256 GB...    ₹35,990
# 918         918  ASUS Vivobook X515EA Core i3 11th Gen - (8 GB/...    ₹36,990
# 919         919  HP Pavilion Intel Core i7 11th Gen - (16 GB/51...    ₹89,999
#
# ...

# %%
df.info()            #gives the info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   920 non-null    int64
#  1   title        920 non-null    object
#  2   price        920 non-null    object
#  3   discount     831 non-null    object
#  4   Processor    920 non-null    object
#  5   RAM          920 non-null    object
#  6   OS           920 non-null    object
#  7   Display      920 non-null    object
#  8   In_build_sw  357 non-null    object
#  9   warranty     906 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 72.0+ KB
